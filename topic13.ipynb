# %% [markdown]
# ### 빅데이터분석개론 토픽13
# - 2024 . 07 . 03
#
# -------
#
# #### 13단원. 시각 데이터 처리
#
# - 이미지 데이터
#     - 이미지 또한 가로, 세로의 픽셀로 이루어져 있기 때문에 2차원 배열
#         - 색상 해상도, 공간 해상도를 가짐
#     - 비트맵(레스터), 벡터 방식으로 구분
#     - 회색조 (흑백) : 색상 없이 밝기 정보만 가지는 이미지
#         - 하나의 채널로 픽셀을 표현 가능 (밝기 채널)
#     - 색상조
#         - 분류 : RGB (저장 good, 처리 bad), HSV (저장 good, 처리 good)
#     - (1) 픽셀 값을 그대로 파일에 옮겨 저장하면 bmp라고 하는 확장자가 됨
#     - (2) bmp를 압축하여 jpg, gif, png로 만듦

# %%
# plt을 이용하여 이미지 출력

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('data/image/mandrill.png')
print (img) # r g b

image_plot = plt.imshow(img) # 이미지 보여주기
plt.show()
# Out:
# [[[0.45882353 0.41960785 0.21960784]
#   [0.26666668 0.22352941 0.14509805]
#   [0.42352942 0.36078432 0.20784314]
#   ...
#   [0.36862746 0.36078432 0.22745098]
#   [0.5254902  0.50980395 0.33333334]
#   [0.56078434 0.60784316 0.40784314]]
#
#  [[0.42352942 0.36078432 0.20784314]
#   [0.32941177 0.3019608  0.1764706 ]
#   [0.32941177 0.3019608  0.1764706 ]
#   ...
#   [0.4117647  0.5019608  0.34901962]
#   [0.36862746 0.35686275 0.29411766]
#   [0.27450982 0.30588236 0.21176471]]
#
#  [[0.45882353 0.41960785 0.21960784]
#   [0.45882353 0.41960785 0.21960784]
#   [0.32941177 0.3019608  0.1764706 ]
#   ...
#   [0.37254903 0.40392157 0.24313726]
#   [0.28235295 0.27450982 0.1764706 ]
#   [0.47058824 0.5372549  0.3529412 ]]
#
#  ...
#
#  [[0.3647059  0.46666667 0.4117647 ]
#   [0.44705883 0.5803922  0.6117647 ]
#   [0.52156866 0.5686275  0.6039216 ]
#   ...
#   [0.36078432 0.41960785 0.34509805]
#   [0.39215687 0.36078432 0.36078432]
#   [0.32941177 0.32156864 0.28627452]]
#
# ...

# %% [markdown]
# -----

# %%
# opencv를 이용하여 이미지 처리 

import cv2 

img_gray = cv2.imread('data/image/mandrill.png', cv2.IMREAD_GRAYSCALE)
img_color = cv2.imread('data/image/mandrill.png', cv2.IMREAD_COLOR)

cv2.imshow('grayscale', img_gray)
cv2.imshow('color image', img_color)

# 아래 두 코드 없으면 떴다가 바로 종료됨 -> 아래 두 코드를 끝에 붙일 것
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 2024-07-03 11:51:43.045 Python[16925:1346032] WARNING: Secure coding is not enabled for restorable state! Enable secure coding by implementing NSApplicationDelegate.applicationSupportsSecureRestorableState: and returning YES.

# %%
# line, arrowedLine, rectangle, putText

# %%
# trackbar 위치 변경 시 투명도 조절

# %% [markdown]
# ---------
#
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202024-07-03%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2011.54.41.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202024-07-03%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2011.54.41.png)
#
# - mask
#     - 이미지의 특정한 부분을 남기거나, 사라지게 하는 기술
#     - 비트 단위의 연산을 취함 (검정색 0, 흰색 1)
#         - &, |, ^

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202024-07-03%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2011.55.39.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202024-07-03%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2011.55.39.png)

# %%
# bitwise_and, bitwise_or, bitwise_xor

# %%
# inrange(), cvtColor()

# %%
# 이미지 필터 씌우기
# 이미지 대비를 바꾸는 것 (이미지가 soft해짐 -> blur)
# filter2D, np.ones()

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202024-07-03%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%2012.04.45.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202024-07-03%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%2012.04.45.png)
#
# - 위의 것은 단순한 blur 처리 (주변에 있는 것들과 평균)
# - 이는 이미지의 고유한 값을 없애버리는 것 -> GaussianBlur을 이용
# - 원본의 특징이 잘 유지되면서 부드러운 이미지 나타남

# %%
# Gaussian Blur

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202024-07-03%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%2012.07.45.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202024-07-03%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%2012.07.45.png)
#
# - salt and pepper : 이미지 주위에 비해 튀는 점
# - 이를 제거하기 위해서 medianBlur 사용
# - 그림으로 그린 것처럼 나타남

# %% [markdown]
# ----------

# %%
# 특정한 임계값 이상인 값과 그렇지 않은 값들을 구분하여 특정 값만 남기는 작업

# %%
# 윤곽선 뽑아내기 
# 이미지에서 가장 중요한 특성 == 윤곽선 (border)
# adaptiveThreshold() 사용
